# %% [markdown]
# ## 5 th analisis
# ### PARA:
#     * 111. **FCC** Lattice statistics, Number of atoms in face centred cubic (fcc) lattice
#     * 112. **HCP** Lattice statistics, Number of atoms in hexagonal closed packed (hcp) lattice
#     * 113. **ICOS** Lattice statistics, Number of atoms in icosahedral lattice
#     * 114.  **DECA** Lattice statistics, Number of atoms in decahedral lattice
# ===================================================================

# %% [markdown]
# # ANALISIS DE DATOS DE NANOPARTICULAS DE ORO
# ### EDA
# #### Autora: Josefina Cresta

# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importación de base de datos

# %%
data = pd.read_csv("/Users/jofi/DEV_THE_BRIDGE_FEB22/EDA/previa/1-Au-DataSet/Au_nanoparticle_dataset.csv")

# %%
data
# Out:
#         ID    T       tau  time  N_total  N_bulk  N_surface        Volume  \
# 0        1  273  0.000025     1     1599    1014        585  2.710000e-26
# 1        2  273  0.000025     2     1642    1034        608  2.780000e-26
# 2        3  273  0.000025     3     4637    3365       1272  7.850000e-26
# 3        4  273  0.000025     4     7189    5292       1897  1.220000e-25
# 4        5  273  0.000025     5    11004    8508       2496  1.860000e-25
# ...    ...  ...       ...   ...      ...     ...        ...           ...
# 3995  3996  973  0.000250     6     1509     950        559  2.550000e-26
# 3996  3997  973  0.000250     7     2315    1469        846  3.920000e-26
# 3997  3998  973  0.000250     8     2764    1905        859  4.680000e-26
# 3998  3999  973  0.000250     9     3148    2199        949  5.330000e-26
# 3999  4000  973  0.000250    10     3986    2785       1201  6.750000e-26
#
#         R_min    R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  \
# ...

# %%
data_5= data.loc[:,['N_total','FCC', 'HCP', 'ICOS', 'DECA','Total_E']]
cols=['N_total','FCC', 'HCP', 'ICOS', 'DECA','Total_E']

# %%
data_5
# Out:
#       N_total   FCC   HCP  ICOS  DECA     Total_E
# 0        1599    24    23     2     8  -5908.6345
# 1        1642    30    35     1     7  -6035.4034
# 2        4637   700   376     0    17 -17330.1660
# 3        7189  1858   823     0    11 -26937.2010
# 4       11004  3575  1350     0    28 -41427.9010
# ...       ...   ...   ...   ...   ...         ...
# 3995     1509     0     0     0     0  -5346.9589
# 3996     2315     0     0     0     0  -8218.1252
# 3997     2764     0     0     0     0  -9876.2899
# 3998     3148     1     1     0     1 -11261.0810
# 3999     3986     0     0     0     0 -14264.3970
#
# [4000 rows x 6 columns]

# %%
data_5.loc[data_5['N_total']==3986, cols]
# Out:
#       N_total  FCC  HCP  ICOS  DECA    Total_E
# 3999     3986    0    0     0     0 -14264.397

# %%
plt.scatter(data_5['N_total'], data_5['DECA'])

# %%
#Creo la grafica con matplot
plt.figure(figsize=(10,10))
plt.title("Comparación resultados GA parametrizado para distintas cantidad de átomos")
plt.xlabel("Cantidad de átomos")
plt.ylabel("Energía [eV/atom]")
plt.scatter(data['N_total'], data['Total_E']/data['N_total'], color="purple")
plt.vlines(236, -3.8, -3.3, color='red')
plt.vlines(147, -3.8, -3.3, color='blue')
plt.vlines(923, -3.8, -3.3, color='blue')
plt.vlines(309, -3.8, -3.3, color='blue')
#plt.xlim(min(data['N_total']), min(data['N_total'])+10)
plt.xlim(200,400)
plt.show()

# %%
#Creo la grafica con matplot
plt.figure(figsize=(10,10))
plt.title("Comparación resultados GA parametrizado para distintas cantidad de átomos")
plt.xlabel("Cantidad de átomos")
plt.ylabel("Energía [eV/atom]")
plt.scatter(data['N_total'], data['Volume']*(10**26), color="purple")
plt.vlines(236, -3.8, -3.3, color='red')
plt.vlines(147, -3.8, -3.3, color='blue')
plt.vlines(923, -3.8, -3.3, color='blue')
plt.vlines(309, -3.8, -3.3, color='blue')
#plt.xlim(min(data['N_total']), min(data['N_total'])+10)
plt.xlim(200,400)
plt.ylim(-0.01,2)

plt.show()

# %%
data.Volume*(10**26)
# Out:
# 0       2.71
# 1       2.78
# 2       7.85
# 3       12.2
# 4       18.6
#         ...
# 3995    2.55
# 3996    3.92
# 3997    4.68
# 3998    5.33
# 3999    6.75
# Name: Volume, Length: 4000, dtype: object

# %%
data_5= data.loc[:,['N_total','FCC', 'HCP', 'ICOS', 'DECA','Total_E']]
data_5.T
# Out:
#               0          1          2          3          4          5     \
# N_total  1599.0000  1642.0000   4637.000   7189.000  11004.000  13375.000
# FCC        24.0000    30.0000    700.000   1858.000   3575.000   5019.000
# HCP        23.0000    35.0000    376.000    823.000   1350.000   1983.000
# ICOS        2.0000     1.0000      0.000      0.000      0.000      0.000
# DECA        8.0000     7.0000     17.000     11.000     28.000     52.000
# Total_E -5908.6345 -6035.4034 -17330.166 -26937.201 -41427.901 -50687.666
#
#              6          7          8          9     ...       3990       3991  \
# N_total  13795.00  13947.000  14020.000  14056.000  ...   398.0000   415.0000
# FCC       5367.00   5441.000   5649.000   5607.000  ...     0.0000     0.0000
# HCP       1972.00   2124.000   2117.000   2086.000  ...     0.0000     0.0000
# ICOS         0.00      0.000      0.000      0.000  ...     0.0000     0.0000
# ...

# %%
data_5= data_5.drop(columns=['ICOS','DECA'])

# %%
data_5['Config_FCC']=(data_5['FCC']>data_5['HCP'])

# %%
data_5
# Out:
#       N_total   FCC   HCP     Total_E  Config_FCC
# 0        1599    24    23  -5908.6345        True
# 1        1642    30    35  -6035.4034       False
# 2        4637   700   376 -17330.1660        True
# 3        7189  1858   823 -26937.2010        True
# 4       11004  3575  1350 -41427.9010        True
# ...       ...   ...   ...         ...         ...
# 3995     1509     0     0  -5346.9589       False
# 3996     2315     0     0  -8218.1252       False
# 3997     2764     0     0  -9876.2899       False
# 3998     3148     1     1 -11261.0810       False
# 3999     3986     0     0 -14264.3970       False
#
# [4000 rows x 5 columns]

# %%
less_923 = data_5[data_5['N_total']<923]

# %%
less_923
# Out:
#       N_total  FCC  HCP  ICOS  DECA    Total_E
# 60        752    0    3     0     1 -2717.5932
# 61        781    3    2     0     0 -2829.3251
# 70        643    7    8     0     1 -2316.9240
# 71        701   10    6     0     2 -2526.7627
# 80        572    0    0     0     2 -2032.7476
# ...       ...  ...  ...   ...   ...        ...
# 3982      879    0    0     0     0 -3084.1457
# 3990      398    0    0     0     0 -1374.0525
# 3991      415    0    0     0     0 -1432.1186
# 3992      723    0    0     0     0 -2533.3208
# 3993      865    0    0     0     0 -3046.8478
#
# [825 rows x 6 columns]

# %%
# Out:
# array([  24,   30,  700, ..., 3240, 3213, 3506])

# %%
config=['FCC', 'HCP', 'ICOS', 'DECA']

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.histplot(x=less_923.N_total, hue=s.species, binwidth=100 )
