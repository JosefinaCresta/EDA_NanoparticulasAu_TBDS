# %% [markdown]
# ## 2th analisis
# ### PARA:
# `Exploracion inicial`
# ===================================================================

# %% [markdown]
# # ANALISIS DE DATOS DE NANOPARTICULAS DE ORO
# ### EDA
# #### Autora: Josefina Cresta

# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importación de base de datos

# %%
data = pd.read_csv("Au_nanoparticle_dataset.csv")

# %%
data
# Out:
#         ID    T       tau  time  N_total  N_bulk  N_surface        Volume  \
# 0        1  273  0.000025     1     1599    1014        585  2.710000e-26
# 1        2  273  0.000025     2     1642    1034        608  2.780000e-26
# 2        3  273  0.000025     3     4637    3365       1272  7.850000e-26
# 3        4  273  0.000025     4     7189    5292       1897  1.220000e-25
# 4        5  273  0.000025     5    11004    8508       2496  1.860000e-25
# ...    ...  ...       ...   ...      ...     ...        ...           ...
# 3995  3996  973  0.000250     6     1509     950        559  2.550000e-26
# 3996  3997  973  0.000250     7     2315    1469        846  3.920000e-26
# 3997  3998  973  0.000250     8     2764    1905        859  4.680000e-26
# 3998  3999  973  0.000250     9     3148    2199        949  5.330000e-26
# 3999  4000  973  0.000250    10     3986    2785       1201  6.750000e-26
#
#         R_min    R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  \
# ...

# %% [markdown]
# # Exploración inicial de la base de datos

# %% [markdown]
# Tamaño
#
# *Retorna un Tuple: (filas, columnas)*

# %%
data.shape
# Out:
# (4000, 185)

# %% [markdown]
# Primeras filas

# %%
data.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %% [markdown]
# Últimas filas

# %%
data.tail()
# Out:
#         ID    T      tau  time  N_total  N_bulk  N_surface        Volume  \
# 3995  3996  973  0.00025     6     1509     950        559  2.550000e-26
# 3996  3997  973  0.00025     7     2315    1469        846  3.920000e-26
# 3997  3998  973  0.00025     8     2764    1905        859  4.680000e-26
# 3998  3999  973  0.00025     9     3148    2199        949  5.330000e-26
# 3999  4000  973  0.00025    10     3986    2785       1201  6.750000e-26
#
#         R_min    R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  \
# 3995  13.8048  23.1729  ...         0         0         0         0         0
# 3996  12.0020  36.7573  ...         0         0         0         0         0
# 3997  18.8611  24.6101  ...         0         0         0         0         0
# 3998  18.7624  26.0008  ...         0         0         0         0         0
# 3999  19.1334  44.7678  ...         0         0         0         0         0
#
# ...

# %% [markdown]
# Sample

# %%
data.sample(5)
# Out:
#         ID    T       tau  time  N_total  N_bulk  N_surface        Volume  \
# 1180  1181  473  0.000225     1      530     251        279  8.970000e-27
# 2707  2708  723  0.000000    10     4496    3250       1246  7.610000e-26
# 1188  1189  473  0.000225     9     2863    1843       1020  4.850000e-26
# 493    494  323  0.000000    10     1504     976        528  2.550000e-26
# 2257  2258  723  0.000000    10      456     229        227  7.720000e-27
#
#         R_min    R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  \
# 1180   5.7055  16.9774  ...         0         0         0         0         0
# 2707  21.8527  28.9965  ...         0         0         0         0         0
# 1188  14.9471  32.2394  ...         0         0         0         0         0
# 493   15.1310  19.2064  ...         0         0         0         0         0
# 2257   8.7085  13.1297  ...         0         0         0         0         0
#
# ...

# %% [markdown]
# Resumen de información del DataFrame, con metodo `.info()` de *Pandas*
#
# Informacion general de los datos de cada cloumna
# * Indica el numero de filas del dataset
# * Muestra el numero de datos No Nulos por columna (valores validos)
# * Tipo de dato de cada columna
# * Tamaño total del dataset
# df.info()*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Columns: 185 entries, ID to Formation_E
# dtypes: float64(23), int64(162)
# memory usage: 5.6 MB

# %% [markdown]
# Tipos de datos que existen en las columnas del dataframe

# %%
data.dtypes
# Out:
# ID               int64
# T                int64
# tau            float64
# time             int64
# N_total          int64
#                 ...
# q6q6_S19         int64
# q6q6_S20         int64
# q6q6_S20+        int64
# Total_E        float64
# Formation_E    float64
# Length: 185, dtype: object

# %%
data.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64')], dtype=object)

# %% [markdown]
# Analisis de las columnas disponibles

# %%
print(data.columns.tolist())
# Out:
# ['ID', 'T', 'tau', 'time', 'N_total', 'N_bulk', 'N_surface', 'Volume', 'R_min', 'R_max', 'R_diff', 'R_avg', 'R_std', 'R_skew', 'R_kurt', 'S_100', 'S_111', 'S_110', 'S_311', 'Curve_1-10', 'Curve_11-20', 'Curve_21-30', 'Curve_31-40', 'Curve_41-50', 'Curve_51-60', 'Curve_61-70', 'Curve_71-80', 'Curve_81-90', 'Curve_91-100', 'Curve_101-110', 'Curve_111-120', 'Curve_121-130', 'Curve_131-140', 'Curve_141-150', 'Curve_151-160', 'Curve_161-170', 'Curve_171-180', 'Avg_total', 'Avg_bulk', 'Avg_surf', 'TCN_0', 'TCN_1', 'TCN_2', 'TCN_3', 'TCN_4', 'TCN_5', 'TCN_6', 'TCN_7', 'TCN_8', 'TCN_9', 'TCN_10', 'TCN_11', 'TCN_12', 'TCN_13', 'TCN_14', 'TCN_15', 'TCN_16', 'TCN_17', 'TCN_18', 'TCN_19', 'TCN_20', 'BCN_0', 'BCN_1', 'BCN_2', 'BCN_3', 'BCN_4', 'BCN_5', 'BCN_6', 'BCN_7', 'BCN_8', 'BCN_9', 'BCN_10', 'BCN_11', 'BCN_12', 'BCN_13', 'BCN_14', 'BCN_15', 'BCN_16', 'BCN_17', 'BCN_18', 'BCN_19', 'BCN_20', 'SCN_0', 'SCN_1', 'SCN_2', 'SCN_3', 'SCN_4', 'SCN_5', 'SCN_6', 'SCN_7', 'SCN_8', 'SCN_9', 'SCN_10', 'S
# ...

# %% [markdown]
# <sca>ANALIZAR COLUMNAS DISPONIBLES

# %% [markdown]
# Descripción con metodo `describe()` de *Pandas*
#
# Resumen de la estadistica descriptiva general de las columnas numericas del dataframe, presenta la informacion de:
#
# * Promedio (mean)
# * Desviacion estandard (std)
# * Valor minimo
# * Valor maximo
# * Cuartiles (25%, 50% y 75%)

# %%
data.describe(include=None)
# Out:
#                 ID            T          tau         time       N_total  \
# count  4000.000000  4000.000000  4000.000000  4000.000000   4000.000000
# mean   2000.500000   615.000000     0.000055     8.200000   3476.786500
# std    1154.844867   223.625808     0.000081     2.856929   3679.286769
# min       1.000000   273.000000     0.000000     1.000000    236.000000
# 25%    1000.750000   410.500000     0.000000     7.000000   1061.000000
# 50%    2000.500000   598.000000     0.000000    10.000000   1867.000000
# 75%    3000.250000   785.500000     0.000100    10.000000   4503.000000
# max    4000.000000   973.000000     0.000250    10.000000  14277.000000
#
#              N_bulk   N_surface        Volume        R_min        R_max  ...  \
# count   4000.000000  4000.00000  4.000000e+03  4000.000000  4000.000000  ...
# mean    2521.550250   955.23625  5.885368e-26    16.436127    26.028875  ...
# std     2976.232459   721.87022  6.227819e-26     6.761951     9.822659  ...
# ...

# %%
data.describe(include=None).T
# Out:
#               count          mean           std          min          25%  \
# ID           4000.0   2000.500000   1154.844867      1.00000   1000.75000
# T            4000.0    615.000000    223.625808    273.00000    410.50000
# tau          4000.0      0.000055      0.000081      0.00000      0.00000
# time         4000.0      8.200000      2.856929      1.00000      7.00000
# N_total      4000.0   3476.786500   3679.286769    236.00000   1061.00000
# ...             ...           ...           ...          ...          ...
# q6q6_S19     4000.0      0.000000      0.000000      0.00000      0.00000
# q6q6_S20     4000.0      0.000000      0.000000      0.00000      0.00000
# q6q6_S20+    4000.0      0.000000      0.000000      0.00000      0.00000
# Total_E      4000.0 -12742.661846  13690.999369 -53772.85400 -16504.67800
# Formation_E  3999.0    851.456017    771.374794     86.06395    334.71275
#
#                     50%         75%          max
# ...

# %% [markdown]
# División

# %%
data.head(1)
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
#
#    q6q6_S20  q6q6_S20+    Total_E  Formation_E
# 0         0          0 -5908.6345     343.4555
#
# [1 rows x 185 columns]

# %%
data_Total= data[['TCN_0', 'TCN_1', 'TCN_2', 'TCN_3', 'TCN_4', 'TCN_5', 'TCN_6', 'TCN_7', 'TCN_8', 'TCN_9', 'TCN_10', 'TCN_11', 'TCN_12', 'TCN_13', 'TCN_14', 'TCN_15', 'TCN_16', 'TCN_17', 'TCN_18', 'TCN_19', 'TCN_20']]

# %%
data_Total
# Out:
#       TCN_0  TCN_1  TCN_2  TCN_3  TCN_4  TCN_5  TCN_6  TCN_7  TCN_8  TCN_9  \
# 0         0      0      0      0      0      2     24     81    146    169
# 1         0      3      2      4      4      6     33     70    138    172
# 2         0      2      2      4     11     17     66    150    246    386
# 3         0      2      3      6     13     43    138    272    369    492
# 4         0      5      1      5     23     49    230    339    503    584
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 3995      0      0      0      0      5     12     53    105    135    144
# 3996      0      1      0      0      5     21     97    156    193    196
# 3997      0      0      0      1      4     23     81    159    217    199
# 3998      0      0      0      0      4     23     94    172    235    232
# 3999      0      0      0      0      3     17    113    218    308    309
#
# ...

# %%
config = data[['N_total','FCC', 'HCP', 'ICOS', 'DECA']]

# %%
config
# Out:
#       N_total   FCC   HCP  ICOS  DECA
# 0        1599    24    23     2     8
# 1        1642    30    35     1     7
# 2        4637   700   376     0    17
# 3        7189  1858   823     0    11
# 4       11004  3575  1350     0    28
# ...       ...   ...   ...   ...   ...
# 3995     1509     0     0     0     0
# 3996     2315     0     0     0     0
# 3997     2764     0     0     0     0
# 3998     3148     1     1     0     1
# 3999     3986     0     0     0     0
#
# [4000 rows x 5 columns]

# %%
config.loc[config['N_total']==config['N_total'].min()]
# Out:
#       N_total  FCC  HCP  ICOS  DECA
# 200       236   74    4     0     0
# 1200      236   22   26     0     4
# 2200      236    0    2     0     0
# 3200      236    0    0     0     0

# %%
config
# Out:
#       N_total   FCC   HCP  ICOS  DECA
# 0         236    24    23     2     8
# 1         236    30    35     1     7
# 2         236   700   376     0    17
# 3         236  1858   823     0    11
# 4         236  3575  1350     0    28
# ...       ...   ...   ...   ...   ...
# 3995      236     0     0     0     0
# 3996      236     0     0     0     0
# 3997      236     0     0     0     0
# 3998      236     1     1     0     1
# 3999      236     0     0     0     0
#
# [4000 rows x 5 columns]

# %%
#Lista de variables locales
cols=['ID', 'T', 'tau', 'time', 'N_total', 'N_bulk', 'N_surface', 'Volume', 'R_avg','Avg_total', 'Avg_bulk', 'Avg_surf', 'N_bonds', 'Avg_bonds', 'Total_E', 'Formation_E']

#Diccionario de traduccioón
traduccion={"ID":           "ID",
            "T":            "Temp",
            "tau":          "Crecimiento", 
            "time":         "Tiempo", 
            "N_total":      "N_total",
            "N_bulk":       "N_bulk",
            "N_surface":    "N_super", 
            "Volume":       "Volumen",
            "R_avg":        "Radio",
            "Avg_total":    "Coord_all",
            "Avg_bulk":     "Coord_bulk",
            "Avg_surf":     "Coord_super",
            "N_bonds":      "N_enlaces",
            "Avg_bonds":    "Long_enlaces",
            "Total_E":      "Total_E",
            "Formation_E":  "Energia_Forma",
}
